# %%
cd /home/yuchen/pulse2percept

# %%
import shapes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pulse2percept as p2p
import pandas as pd
import skimage
from skimage.measure import label, regionprops, regionprops_table
import math
import string
from statistics import mean
from sklearn.linear_model import LinearRegression
import shapely.geometry as geom
import cv2 
from sklearn.linear_model import LinearRegression
import shapely.geometry as geom
import statsmodels.api as sm 
import pingouin as pg
from statsmodels.stats.outliers_influence import variance_inflation_factor
from matplotlib.ticker import FormatStrFormatter, MaxNLocator, MultipleLocator

# %%
data = shapes.load_shapes("/home/yuchen/shapes/data/shapes.h5", subjects=['12-005','51-009','52-001'],stim_class=None)

double = data[data.electrode2 != str()].reset_index(drop=True)
s4 = double[double.subject == '52-001'].reset_index(drop=True)
stim_class = []
for i in range(len(s4)):
    if 'VCF1' in s4.filename[i]:
        stim_class.append('MultiElectrode')
    else:
        stim_class.append('SpatialSummation')
s4['stim_class'] = stim_class    
double = data[data.electrode2 != str()].reset_index(drop=True)
s3 = double[double.subject == '51-009'].reset_index(drop=True)
stim_class = []
for i in range(len(s3)):
    if 'VCF1' in s3.filename[i]:
        stim_class.append('MultiElectrode')
    else:
        stim_class.append('SpatialSummation')
s3['stim_class'] = stim_class
double = data[data.electrode2 != str()].reset_index(drop=True)
s2 = double[double.subject == '12-005'].reset_index(drop=True)
stim_class = []
for i in range(len(s2)):
    if 'set A' in s2.filename[i] or 'set C' in s2.filename[i] :
        stim_class.append('MultiElectrode')
    else:
        stim_class.append('SpatialSummation')
s2['stim_class'] = stim_class
double_recreated = pd.concat([s2,s3,s4]).reset_index(drop=True)
single = data[data.electrode2 == str()]
single['stim_class'] = 'SingleElectrode'
data = pd.concat([single,double_recreated]).reset_index(drop=True)

# %%
temp = data[data.stim_class != 'SpatialSummation']
temp = temp[temp.area >=10]
temp.groupby(['subject','stim_class', 'amp1','freq']).count()
# temp.groupby(['stim_class']).count()

# %%
# calculate shapes 
result = pd.DataFrame({})
for i in range(len(data)):
    label_img = skimage.measure.label(data['image'][i]>0)
    regions = regionprops(label_img)
    props = regionprops_table(label_img, properties=('centroid',
                                                     'orientation',
                                                     'major_axis_length',
                                                     'minor_axis_length',
                                                     'area',
                                                    'eccentricity',
                                                    'perimeter'))
    df = pd.DataFrame(props).astype('object')
    df.at[0,'centroid-0'] = df.iloc[:, 0].tolist()  # store centroid-x
    df.at[0,'centroid-1'] = df.iloc[:, 1].tolist()  # store centroid-y
    df.at[0,'orientation'] = df.iloc[:, 2].tolist()  # store orientation
    df.at[0,'major_axis_length'] = df.iloc[:, 3].tolist()  # major
    df.at[0,'minor_axis_length'] = df.iloc[:, 4].tolist()  # minor
    df.at[0,'area'] = df.iloc[:, 5].tolist()  # area
    df.at[0,'eccentricity'] = df.iloc[:, 6].tolist()  
    df.at[0,'perimeter'] = df.iloc[:, 7].tolist()  
    result = pd.concat([result, df.iloc[:1,:]],axis=0)

result = result.rename(columns={"area":"size", "orientation":"orientation_new", "eccentricity":"eccentricity_new" })
data = pd.concat([data,result.reset_index(drop=True)],axis=1)
data_copy = data.copy()

# %%
count_0 = 0
count_1 = 0
test = []
lst = []
for i in range(len(data)):
    if data.electrode2[i] == str():
        lst.append('SingleElectrode')
    else:
        lst.append(data.stim_class[i])
data['stim_class'] = lst

cate = data[['subject','amp1','freq','electrode1','electrode2','stim_class']].drop_duplicates().reset_index(drop=True)

img = []
for i in range(len(cate)):
    df = data[(data['subject'] == cate['subject'][i]) & 
              (data['amp1'] == cate['amp1'][i]) & 
              (data['electrode1'] == cate['electrode1'][i]) &
              (data['electrode2'] == cate['electrode2'][i]) & 
              (data['stim_class'] == cate['stim_class'][i])
             ].reset_index(drop=True)
    if df.empty:
        img.append(np.zeros((384, 512)))
    else:
        if df.electrode2[0] == str():  # single electrode 
            if (len(df[df['num_regions']>1])/(len(df))) <= 0.1:
                count_1 += 1
                df_1 = df[df['num_regions'] == 1].reset_index(drop=True)

                df_centroid_0_avg = 0
                df_centroid_1_avg = 0
                for item in range(len(df_1)):
                    df_centroid_0_avg = df_centroid_0_avg + df_1['centroid-0'][item][0]
                    df_centroid_1_avg = df_centroid_1_avg + df_1['centroid-1'][item][0]
                df_centroid_0_avg = df_centroid_0_avg/len(df_1)
                df_centroid_1_avg = df_centroid_1_avg/len(df_1)

                # for drawings with more than one phosphenes, select the one with centroid cloest to the averaged centroid
                df_2 = df[df['num_regions'] > 1].reset_index(drop=True)
                if len(df_2) != 0:
                    for double_number in range(len(df_2)):
                        phosphene_id = 0
                        distance = 9999999
                        for double_item in range(len(df_2['centroid-0'][double_number])):
                            distance_temp = (df_2['centroid-0'][double_number][double_item] - df_centroid_0_avg)**2 + (df_2['centroid-1'][double_number][double_item] - df_centroid_1_avg)**2
                            if distance_temp < distance:
                                distance = distance_temp
                                phosphene_id = double_item
                        df_2.at[double_number,'centroid-0'] = [df_2['centroid-0'][double_number][phosphene_id]]
                        df_2.at[double_number,'centroid-1'] = [df_2['centroid-1'][double_number][phosphene_id]]

                df = pd.concat([df_1,df_2], axis=0).reset_index(drop=True)
                image_temp = np.zeros((len(df['image'][0]),len(df['image'][0][0])))
                for image in range(len(df)):
                    image_temp = image_temp + p2p.utils.images.shift_image(df['image'][image],df_centroid_1_avg-df['centroid-1'][image][0], df_centroid_0_avg-df['centroid-0'][image][0])
                image_temp = image_temp / len(df)
                img.append(image_temp)

            else:  
                phosphene1 = np.mean([p2p.utils.images.center_image(skimage.measure.label(image) == 1) for image in df.image], axis=0)
                phosphene2 = np.mean([p2p.utils.images.center_image(skimage.measure.label(image) == 2) for image in df.image], axis=0)
                phosphene1_centroid = np.mean([regionprops(skimage.measure.label(image>0))[0].centroid for image in df.image], axis=0)
                if sum(sum(phosphene2)) != 0:
                    count = (0,0)
                    phosphene2_centroid = 0
                    for image in df.image:
                        if len(regionprops(skimage.measure.label(image>0))) >= 2:
                            count = (count[0] + regionprops(skimage.measure.label(image>0))[1].centroid[0],count[1] + regionprops(skimage.measure.label(image>0))[1].centroid[1]) 
                            phosphene2_centroid += 1
                    phosphene2_centroid = (count[0] / phosphene2_centroid,count[1] / phosphene2_centroid)
                y_center, x_center = phosphene1.shape[0] / 2, phosphene1.shape[1] / 2
                phosphene1 = p2p.utils.images.shift_image(phosphene1, phosphene1_centroid[1] - x_center, phosphene1_centroid[0] - y_center)
                if sum(sum(phosphene2)) != 0:
                    phosphene2 = p2p.utils.images.shift_image(phosphene2, phosphene2_centroid[1] - x_center, phosphene2_centroid[0] - y_center)
                    image_temp = phosphene1 + phosphene2
                else:
                    image_temp = phosphene1
                test.append(image_temp)
                img.append(image_temp)
        elif df.electrode2[0] != str():  # double electrode
            phosphene1 = np.mean([p2p.utils.images.center_image(skimage.measure.label(image) == 1) for image in df.image], axis=0)
            phosphene2 = np.mean([p2p.utils.images.center_image(skimage.measure.label(image) == 2) for image in df.image], axis=0)
            phosphene1_centroid = np.mean([regionprops(skimage.measure.label(image>0))[0].centroid for image in df.image], axis=0)
            if sum(sum(phosphene2)) != 0:
                count = (0,0)
                phosphene2_centroid = 0
                for image in df.image:
                    if len(regionprops(skimage.measure.label(image>0))) >= 2:
                        count = (count[0] + regionprops(skimage.measure.label(image>0))[1].centroid[0],count[1] + regionprops(skimage.measure.label(image>0))[1].centroid[1]) 
                        phosphene2_centroid += 1
                phosphene2_centroid = (count[0] / phosphene2_centroid,count[1] / phosphene2_centroid)
            y_center, x_center = phosphene1.shape[0] / 2, phosphene1.shape[1] / 2
            phosphene1 = p2p.utils.images.shift_image(phosphene1, phosphene1_centroid[1] - x_center, phosphene1_centroid[0] - y_center)
            if sum(sum(phosphene2)) != 0:
                phosphene2 = p2p.utils.images.shift_image(phosphene2, phosphene2_centroid[1] - x_center, phosphene2_centroid[0] - y_center)
                image_temp = phosphene1 + phosphene2
            else:
                image_temp = phosphene1
            test.append(image_temp)
            img.append(image_temp)
            
cate['avg_image'] = img

# %%
cate = cate[cate.stim_class != 'SpatialSummation'].reset_index(drop=True)
cate

# %%
centroid0 = []
centroid1 = []
props_ct = []

for i in range(len(cate)):
    img = cate['avg_image'][i]
    props = regionprops(skimage.measure.label(img>0))
    ct = len(props)
    centroid = []
    for j in range(ct):
        centroid.append((props[j].centroid[1], props[j].centroid[0]))
    if i==152: centroid = [centroid[0], centroid[-1]]
    elif ct > 2:  centroid = [centroid[0], centroid[1]]
    centroid0.append(centroid[0])
    props_ct.append(ct)
    if ct>1: centroid1.append(centroid[1])
    else: centroid1.append(tuple())
    
cate['props_ct'] = props_ct
cate['centroid0'] = centroid0
cate['centroid1'] = centroid1

# %%
cate

# %%
implant_dict = {'12-005': None, '51-009': None, '52-001': None}
for subj in implant_dict.keys():
    s2 = shapes.subject_params[subj]
    implant, model = shapes.model_from_params(s2, biphasic=False)
    implant_dict[subj] = implant

# %%
coord_dict = {'12-005': None, '51-009': None, '52-001': None}

for subj in coord_dict.keys():
    x_max = 0 
    x_min = 10000
    y_max = 0 
    y_min = 10000
    s2 = shapes.subject_params[subj]
    implant, model = shapes.model_from_params(s2, biphasic=False)
    for letter in range(ord('A'), ord('F') + 1):
        for i in range(1,11):
            e = str(chr(letter) + str(i))
            x_cur = implant[e].x
            if x_cur > x_max: x_max=x_cur
            if x_cur < x_min: x_min=x_cur
                
            y_cur = implant[e].y
            if y_cur > y_max: y_max=y_cur
            if y_cur < y_min: y_min=y_cur
    coord_dict[subj] = {'x': [x_max-x_min, x_min/(x_max-x_min)], 'y': [y_max-y_min, y_min/(y_max-y_min)]}

# %%
coord_dict

# %%
def normalize_image(img):
    norm_img = cv2.normalize(img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
    return cv2.convertScaleAbs(norm_img)

def draw_contours(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 20, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contour_img = np.zeros_like(image)
    cv2.drawContours(contour_img, contours, -1, (255, 255, 255), 2)  # Change thickness as needed
    return contour_img

# %%
double = cate[cate.electrode2 != str()].reset_index(drop=True)
single = cate[cate.electrode2 == str()].reset_index(drop=True)
height,width = cate['avg_image'].iloc[0].shape
y_center,x_center = height/2,width/2 

scale_dict = {0: 1.5, 1:1.5, 2:1.2,
             3:1, 4:1, 5:1,
             6:1.2, 7:1.2, 8:1,}

scale_dict_electrode = {0: 5, 1: 3.5 ,2:3,
                        3:1.8, 4:0.8, 5:1,
                         6:1.1, 7:3, 8:1,}

shift_dict = {0:[-117,35], 1:[-75,10], 2:[-170,30], 
              3:[-143,30], 4:[-55,-25], 5:[-197,23], 
              6:[-70,80], 7:[-180,70], 8:[-130,0], 
}

fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 40))
fig.tight_layout()
row = 0
# for i in [ 22, 29, 39, 55, 78 , 80, 87, 96, 103]:
# for i in [ 22, 13, 39, 55, 78 , 80, 87, 96, 103]:
for i in [ 22, 13, 39, 55, 78 , 75, 87, 96, 103]: 

    e1 = double.electrode1[i]
    e2 = double.electrode2[i]
    freq = double.freq[i]
    amp1 = double.amp1[i]
    subject = double.subject[i]
        
    e1_x = (implant_dict[subject][e1].x / coord_dict[subject]['x'][0] - coord_dict[subject]['x'][1]*scale_dict_electrode[row]) * width / scale_dict_electrode[row]
    e1_y = (implant_dict[subject][e1].y / coord_dict[subject]['y'][0] - coord_dict[subject]['y'][1]*scale_dict_electrode[row]) * height / scale_dict_electrode[row]
    e2_x = (implant_dict[subject][e2].x / coord_dict[subject]['x'][0] - coord_dict[subject]['x'][1]*scale_dict_electrode[row]) * width / scale_dict_electrode[row]
    e2_y = (implant_dict[subject][e2].y / coord_dict[subject]['y'][0] - coord_dict[subject]['y'][1]*scale_dict_electrode[row]) * height / scale_dict_electrode[row]
        
    single1 = single[(single.electrode1 == e1) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
    single2 = single[(single.electrode1 == e2) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        
    new_height = int(round(single1.avg_image.iloc[0].shape[0]/scale_dict[row],0))
    new_width = int(round(single1.avg_image.iloc[0].shape[1]/scale_dict[row],0))

    if i == 87:
        e1_img = p2p.utils.images.shift_image(single1.avg_image.iloc[0],-100,0)
        e2_img = p2p.utils.images.shift_image(single2.avg_image.iloc[0], -100, 0)  
        e1_img = p2p.utils.images.shift_image(e1_img, e1_x-single1.centroid0.iloc[0][0], e1_y-single1.centroid0.iloc[0][1])
        e2_img = p2p.utils.images.shift_image(e2_img, e2_x-single2.centroid0.iloc[0][0], e2_y-single2.centroid0.iloc[0][1])
    else:  
        e1_img = p2p.utils.images.shift_image(single1.avg_image.iloc[0], e1_x-single1.centroid0.iloc[0][0], e1_y-single1.centroid0.iloc[0][1])
        e2_img = p2p.utils.images.shift_image(single2.avg_image.iloc[0], e2_x-single2.centroid0.iloc[0][0], e2_y-single2.centroid0.iloc[0][1])
    
        
    e1_img = cv2.resize(e1_img, (new_width, new_height))
    e2_img = cv2.resize(e2_img, (new_width, new_height))   
    comb_img = cv2.resize(double.avg_image[i], (new_width, new_height))
    
    colormap = cv2.COLORMAP_COOL  
    e1_img_norm = normalize_image(e1_img)
    e2_img_norm = normalize_image(e2_img)
    e1_colored = cv2.applyColorMap(e1_img_norm, cv2.COLORMAP_HOT)
    e2_colored = cv2.applyColorMap(e2_img_norm, cv2.COLORMAP_HOT)
    
    e2_colored[:, :, [0, 2]] = e2_colored[:, :, [2, 0]]
    
    pred_img = cv2.addWeighted(e1_colored, 1, e2_colored, 1, 0)
    pred_img = 255 - pred_img

    e1_contours = draw_contours(e1_colored)
    e2_contours = draw_contours(e2_colored)
    
    e1_contours[:,:,0] = 0
    e2_contours[:,:,2] = 0
    blended_contours = cv2.addWeighted(e1_contours, 1, e2_contours, 1, 0)
    blended_contours = 255 - blended_contours
    
    comb_img = 255 - np.stack((normalize_image(comb_img),)*3, axis=-1)
    
    M = np.float32([[1, 0, shift_dict[row][0]], [0, 1, shift_dict[row][1]]])  
    blended_contours_map = cv2.warpAffine(blended_contours, M, (blended_contours.shape[1], blended_contours.shape[0]),borderValue=(255, 255, 255))
    blended_contours_map = cv2.addWeighted(blended_contours_map, 0.5,comb_img, 0.5, 0)
    
    axs[row,0].imshow(pred_img)
    axs[row,1].imshow(comb_img)
    axs[row,2].imshow(blended_contours_map)

    axs[row, 0].text(0.02, 0.02, str(e1), transform=axs[row, 0].transAxes, ha='left', va='bottom', color='red', fontsize=64)
    axs[row, 0].text(0.98, 0.02, ' ' + str(e2), transform=axs[row, 0].transAxes, ha='right', va='bottom', color='blue', fontsize=64)
    axs[row, 1].text(0.5, 0.02, str(e1) + '+' + str(e2), transform=axs[row, 1].transAxes, ha='center', va='bottom', color='black', fontsize=64)
        
    for j in range(3):
        axs[row,j].set_xticks([])
        axs[row,j].set_yticks([])
        
    axs[row, 0].text(-0.15, 0.1, str(row+1), transform=axs[row, 0].transAxes, ha='left', va='center', color='black', fontsize=64, rotation=0)
    axs[4, 0].text(-0.35, 0.05, str('Row'), transform=axs[4, 0].transAxes, ha='left', va='center', color='black', fontsize=64, rotation=90)
        
        
    row += 1

axs[0,0].set(xlim=(160,360), ylim=(230,80))  
axs[1,0].set(xlim=(160,360), ylim=(240,90)) 
axs[2,0].set(xlim=(225,425), ylim=(260,110))  
axs[3,0].set(xlim=(250,450), ylim=(250,100))  
axs[4,0].set(xlim=(250,450), ylim=(330,180))
axs[5,0].set(xlim=(350,550), ylim=(260,110)) 
axs[6,0].set(xlim=(220,420), ylim=(175,25)) 
axs[7,0].set(xlim=(225,425), ylim=(240,90)) 
axs[8,0].set(xlim=(225,425), ylim=(300,150)) 
for col in range(1,3):
    axs[0,col].set(xlim=(50,250), ylim=(250,100))  
    axs[1,col].set(xlim=(70,270), ylim=(240,90))  
    axs[2,col].set(xlim=(40,240), ylim=(290,140))    
    axs[3,col].set(xlim=(110,310), ylim=(280,130))  
    axs[4,col].set(xlim=(200,400), ylim=(310,160))  
    axs[5,col].set(xlim=(150,350), ylim=(280,110)) 
    axs[6,col].set(xlim=(120,320), ylim=(250,100)) 
    axs[7,col].set(xlim=(30,230), ylim=(310,160))   
    axs[8,col].set(xlim=(100,300), ylim=(300,150))    
    
plt.tight_layout()

# %%
fig.savefig("/home/yuchen/shapes/figures/eea_map.pdf", format="pdf", bbox_inches="tight", transparent=True)

# %%
double = cate[cate.electrode2 != str()].reset_index(drop=True)
single = cate[cate.electrode2 == str()].reset_index(drop=True)

for i in range(len(double)):
#     plt.figure()
#     plt.imshow(double.avg_image[i])
    e1 = double.electrode1[i]
    e2 = double.electrode2[i]
    freq = double.freq[i]
    amp1 = double.amp1[i]
    subject = double.subject[i]
#     if e1 in single.electrode1.tolist() and e2 in single.electrode1.tolist():
    single1 = single[(single.electrode1 == e1) & (single.freq == freq) &
                            (single.amp1 == amp1) & (single.subject == subject)]
    single2 = single[(single.electrode1 == e2) & (single.freq == freq) &
                            (single.amp1 == amp1) & (single.subject == subject)]
    if len(single1) + len(single2) == 2:
        fig, axs= plt.subplots(ncols=3, nrows = 1, figsize=(21, 7))
        axs[0].imshow(single1.avg_image.iloc[0])
        axs[0].set_title(e1)
        axs[1].imshow(single2.avg_image.iloc[0])
        axs[1].set_title(e2)
        axs[2].imshow(double.avg_image[i])
        fig.suptitle('index: ' + str(i) + ' subject: ' + str(double.subject[i]))

'''
note for good index:
eem: 7, 22, 25, 29, 48, 49, 53, 64, 73, 113, 121, 126
eea: [18, 20, 24, 57, 79, 83, 85, 102, 106, 108, 123]:
'''

# %%
# eea
double = cate[cate.electrode2 != str()].reset_index(drop=True)
single = cate[cate.electrode2 == str()].reset_index(drop=True)

scale_dict = {0: 1.5, 1:1.5, 2:1.2,
             3:1, 4:1, 5:1,
             6:1.2, 7:1.2, 8:1,}

fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 40))
fig.tight_layout()

row = 0

# for i in [ 24, 31, 41, 57, 79 , 85, 93, 102, 108]:
# for i in [ 22, 13, 39, 55, 78 , 80, 87, 96, 103]:
for i in [ 22, 13, 39, 55, 78 , 75, 87, 96, 103]: 
        e1 = double.electrode1[i]
        e2 = double.electrode2[i]
        freq = double.freq[i]
        amp1 = double.amp1[i]
        subject = double.subject[i]
        single1 = single[(single.electrode1 == e1) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        single2 = single[(single.electrode1 == e2) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        
        new_height = int(round(single1.avg_image.iloc[0].shape[0]/scale_dict[row],0))
        new_width = int(round(single1.avg_image.iloc[0].shape[1]/scale_dict[row],0))
        axs[row,0].imshow(cv2.resize(single1.avg_image.iloc[0], (new_width, new_height)), cmap = 'gray_r')
        axs[row,1].imshow(cv2.resize(single2.avg_image.iloc[0], (new_width, new_height)), cmap = 'gray_r')       
        axs[row,2].imshow(cv2.resize(double.avg_image[i], (new_width, new_height)), cmap = 'gray_r')
        
        axs[row, 0].text(0.98, 0.02, str(e1), transform=axs[row, 0].transAxes,
                     ha='right', va='bottom', color='black', fontsize=64)
        axs[row, 1].text(0.98, 0.02, str(e2), transform=axs[row, 1].transAxes,
                         ha='right', va='bottom', color='black', fontsize=64)
        axs[row, 2].text(0.98, 0.02, str(e1) + '+' + str(e2), transform=axs[row, 2].transAxes,
                         ha='right', va='bottom', color='black', fontsize=64)
        
        axs[row, 0].text(-0.15, 0.1, str(row+1), transform=axs[row, 0].transAxes,
                     ha='left', va='center', color='black', fontsize=64, rotation=0)
        axs[4, 0].text(-0.35, 0.05, str('Row'), transform=axs[4, 0].transAxes,
                     ha='left', va='center', color='black', fontsize=64, rotation=90)
        
        for j in range(3):
            axs[row,j].set_xticks([])
            axs[row,j].set_yticks([])
        
        row += 1
        
for col in range(3):
    axs[0,col].set(xlim=(50,250), ylim=(250,100))  
    axs[1,col].set(xlim=(70,270), ylim=(240,90))  
    axs[2,col].set(xlim=(40,240), ylim=(260,110))    
    axs[3,col].set(xlim=(110,310),ylim=(280,130)) 
    axs[4,col].set(xlim=(200,400), ylim=(310,160))  
    axs[4,0].set(xlim=(200,400), ylim=(260,110))    
    axs[5,col].set(xlim=(150,350), ylim=(310,160)) 
    axs[5,2].set(xlim=(150,350), ylim=(280,130)) 
    axs[6,col].set(xlim=(120,320), ylim=(240,90)) 
    axs[6,2].set(xlim=(120,320), ylim=(250,100)) 
    axs[7,col].set(xlim=(70,270), ylim=(310,160))   
    axs[8,col].set(xlim=(100,300), ylim=(310,160))

# %%
fig.savefig("/home/yuchen/shapes/figures/eea.pdf", format="pdf", bbox_inches="tight", transparent=True)

# %%
double = cate[cate.electrode2 != str()].reset_index(drop=True)
single = cate[cate.electrode2 == str()].reset_index(drop=True)
height,width = cate['avg_image'].iloc[0].shape
y_center,x_center = height/2,width/2 

scale_dict = {0: 1, 1:1, 2:1,
             3:1, 4:1.5, 5:1.2,
             6:1, 7:1, 8:1,}

scale_dict_electrode = {0: 30, 1:2 ,2:2,
                        3:2, 4:2, 5:2,
                         6:1, 7:2, 8:2,}

shift_dict = {0:[-140,0], 1:[-90,70], 2:[-225,100], 
              3:[-150,73], 4:[-35,-5], 5:[-60,15], 
              6:[-100,70], 7:[-195,45], 8:[-155,70], 
}

fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 40))
fig.tight_layout()
row = 0
for i in [ 23, 27, 41, 51, 56, 63, 98,112, 120]:  #  # 17, 25
    e1 = double.electrode1[i]
    e2 = double.electrode2[i]
    freq = double.freq[i]
    amp1 = double.amp1[i]
    subject = double.subject[i]
        
    e1_x = (implant_dict[subject][e1].x / coord_dict[subject]['x'][0] - coord_dict[subject]['x'][1]*scale_dict_electrode[row]) * width / scale_dict_electrode[row]
    e1_y = (implant_dict[subject][e1].y / coord_dict[subject]['y'][0] - coord_dict[subject]['y'][1]*scale_dict_electrode[row]) * height / scale_dict_electrode[row]
    e2_x = (implant_dict[subject][e2].x / coord_dict[subject]['x'][0] - coord_dict[subject]['x'][1]*scale_dict_electrode[row]) * width / scale_dict_electrode[row]
    e2_y = (implant_dict[subject][e2].y / coord_dict[subject]['y'][0] - coord_dict[subject]['y'][1]*scale_dict_electrode[row]) * height / scale_dict_electrode[row]
        
    single1 = single[(single.electrode1 == e1) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
    single2 = single[(single.electrode1 == e2) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        
    new_height = int(round(single1.avg_image.iloc[0].shape[0]/scale_dict[row],0))
    new_width = int(round(single1.avg_image.iloc[0].shape[1]/scale_dict[row],0))

    if i == 87:
        e1_img = p2p.utils.images.shift_image(single1.avg_image.iloc[0],-100,0)
        e2_img = p2p.utils.images.shift_image(single2.avg_image.iloc[0], -100, 0)  
        e1_img = p2p.utils.images.shift_image(e1_img, e1_x-single1.centroid0.iloc[0][0], e1_y-single1.centroid0.iloc[0][1])
        e2_img = p2p.utils.images.shift_image(e2_img, e2_x-single2.centroid0.iloc[0][0], e2_y-single2.centroid0.iloc[0][1])
    else:  
        e1_img = p2p.utils.images.shift_image(single1.avg_image.iloc[0], e1_x-single1.centroid0.iloc[0][0], e1_y-single1.centroid0.iloc[0][1])
        e2_img = p2p.utils.images.shift_image(single2.avg_image.iloc[0], e2_x-single2.centroid0.iloc[0][0], e2_y-single2.centroid0.iloc[0][1])
    
        
    e1_img = cv2.resize(e1_img, (new_width, new_height))
    e2_img = cv2.resize(e2_img, (new_width, new_height))   
    comb_img = cv2.resize(double.avg_image[i], (new_width, new_height))
    
    colormap = cv2.COLORMAP_COOL 
    e1_img_norm = normalize_image(e1_img)
    e2_img_norm = normalize_image(e2_img)
    e1_colored = cv2.applyColorMap(e1_img_norm, cv2.COLORMAP_HOT)
    e2_colored = cv2.applyColorMap(e2_img_norm, cv2.COLORMAP_HOT)
    
    e2_colored[:, :, [0, 2]] = e2_colored[:, :, [2, 0]]
    
    pred_img = cv2.addWeighted(e1_colored, 1, e2_colored, 1, 0)
    pred_img = 255 - pred_img

    e1_contours = draw_contours(e1_colored)
    e2_contours = draw_contours(e2_colored)
    
    e1_contours[:,:,0] = 0
    e2_contours[:,:,2] = 0
    blended_contours = cv2.addWeighted(e1_contours, 1, e2_contours, 1, 0)
    blended_contours = 255 - blended_contours
    
    comb_img = 255 - np.stack((normalize_image(comb_img),)*3, axis=-1)
    
    M = np.float32([[1, 0, shift_dict[row][0]], [0, 1, shift_dict[row][1]]])  
    blended_contours_map = cv2.warpAffine(blended_contours, M, (blended_contours.shape[1], blended_contours.shape[0]),borderValue=(255, 255, 255))
    blended_contours_map = cv2.addWeighted(blended_contours_map, 0.5,comb_img, 0.5, 0)
    
    axs[row,0].imshow(pred_img)
    axs[row,1].imshow(comb_img)
    axs[row,2].imshow(blended_contours_map)

    axs[row, 0].text(0.02, 0.02, str(e1), transform=axs[row, 0].transAxes, ha='left', va='bottom', color='red', fontsize=64)
    axs[row, 0].text(0.98, 0.02, ' ' + str(e2), transform=axs[row, 0].transAxes, ha='right', va='bottom', color='blue', fontsize=64)
    axs[row, 1].text(0.5, 0.02, str(e1) + '+' + str(e2), transform=axs[row, 1].transAxes, ha='center', va='bottom', color='black', fontsize=64)
      
    if subject == '12-005': subject_id = 1
    if subject == '51-009': subject_id = 2
    if subject == '52-001': subject_id = 3
    axs[row, 2].text(1.15, 0.1, str(subject_id), transform=axs[row, 2].transAxes,ha='right', va='center', color='black', fontsize=64, rotation=0)
    axs[4, 2].text(1.4, 0.05, str('Subject'), transform=axs[4, 2].transAxes, ha='right', va='center', color='black', fontsize=64, rotation=-90)
        
    for j in range(3):
        axs[row,j].set_xticks([])
        axs[row,j].set_yticks([])
        
    row += 1

axs[0,0].set(xlim=(300,500), ylim=(320,170))  
axs[1,0].set(xlim=(250,450), ylim=(270,120)) 
axs[2,0].set(xlim=(312,512), ylim=(235,85))  
axs[3,0].set(xlim=(225,425), ylim=(190,40))  
axs[4,0].set(xlim=(50,250), ylim=(240,90))
axs[5,0].set(xlim=(150,350), ylim=(260,110)) 
axs[6,0].set(xlim=(195,395), ylim=(150,0)) 
axs[7,0].set(xlim=(340,540), ylim=(260,110)) 
axs[8,0].set(xlim=(290,490), ylim=(190,40)) 
for col in range(1,3):
    axs[0,col].set(xlim=(170,370), ylim=(310,160))  
    axs[1,col].set(xlim=(150,350), ylim=(330,180))  
    axs[2,col].set(xlim=(100,300), ylim=(330,180))    
    axs[3,col].set(xlim=(70,270), ylim=(260,110))  
    axs[4,col].set(xlim=(30,230), ylim=(240,90))  
    axs[5,col].set(xlim=(90,290), ylim=(260,110)) 
    axs[6,col].set(xlim=(100,300), ylim=(230,80)) 
    axs[7,col].set(xlim=(160,360), ylim=(310,160))   
    axs[8,col].set(xlim=(120,320), ylim=(270,120))     
# plt.tight_layout()

# %%
fig.savefig("/home/yuchen/shapes/figures/eem_map.pdf", format="pdf", bbox_inches="tight", transparent=True)

# %%
# eem
double = cate[cate.electrode2 != str()].reset_index(drop=True)
single = cate[cate.electrode2 == str()].reset_index(drop=True)

scale_dict = {0: 1, 1:1, 2:1,
             3:1, 4:1.5, 5:1.2,
             6:1, 7:1, 8:1,}

fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 40))
fig.tight_layout()

row = 0

# for i in [ 25, 29, 43, 53, 65, 67, 104,113, 121]:
for i in [ 23, 27, 41, 51, 56, 63, 98,112, 120]:
        e1 = double.electrode1[i]
        e2 = double.electrode2[i]
        freq = double.freq[i]
        amp1 = double.amp1[i]
        subject = double.subject[i]
        if subject == '12-005': subject_id = 1
        if subject == '51-009': subject_id = 2
        if subject == '52-001': subject_id = 3
        single1 = single[(single.electrode1 == e1) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        single2 = single[(single.electrode1 == e2) & (single.freq == freq) &
                                (single.amp1 == amp1) & (single.subject == subject)]
        
        new_height = int(round(single1.avg_image.iloc[0].shape[0]/scale_dict[row],0))
        new_width = int(round(single1.avg_image.iloc[0].shape[1]/scale_dict[row],0))
        axs[row,0].imshow(cv2.resize(single1.avg_image.iloc[0], (new_width, new_height)), cmap = 'gray_r')
        axs[row,1].imshow(cv2.resize(single2.avg_image.iloc[0], (new_width, new_height)), cmap = 'gray_r')       
        axs[row,2].imshow(cv2.resize(double.avg_image[i], (new_width, new_height)), cmap = 'gray_r')
        
        axs[row, 0].text(0.98, 0.02, str(e1), transform=axs[row, 0].transAxes,
                     ha='right', va='bottom', color='black', fontsize=64)
        axs[row, 1].text(0.98, 0.02, str(e2), transform=axs[row, 1].transAxes,
                         ha='right', va='bottom', color='black', fontsize=64)
        axs[row, 2].text(0.98, 0.02, str(e1) + '+' + str(e2), transform=axs[row, 2].transAxes,
                         ha='right', va='bottom', color='black', fontsize=64)
        
        axs[row, 2].text(1.15, 0.1, str(subject_id), transform=axs[row, 2].transAxes,
                     ha='right', va='center', color='black', fontsize=64, rotation=0)
         
        axs[4, 2].text(1.4, 0.05, str('Subject'), transform=axs[4, 2].transAxes,
                     ha='right', va='center', color='black', fontsize=64, rotation=-90)
    
        for j in range(3):
            axs[row,j].set_xticks([])
            axs[row,j].set_yticks([])
        
        row += 1
        
for col in range(3):
    axs[0,col].set(xlim=(170,370), ylim=(310,160))  
    axs[1,col].set(xlim=(150,350), ylim=(330,180))  
    axs[2,col].set(xlim=(100,300), ylim=(280,130)) 
    axs[2,2].set(xlim=(100,300), ylim=(330,180))    
    axs[3,col].set(xlim=(50,250), ylim=(220,70))
    axs[3,2].set(xlim=(70,270), ylim=(260,110))  
    axs[4,col].set(xlim=(30,230), ylim=(240,90))  
    axs[5,col].set(xlim=(90,290), ylim=(260,110)) 
    axs[6,col].set(xlim=(100,300), ylim=(240,90)) 
    axs[7,col].set(xlim=(160,360), ylim=(310,160))   
    axs[8,col].set(xlim=(120,320), ylim=(250,100))

# %%
fig.savefig("/home/yuchen/shapes/figures/eem.pdf", format="pdf", bbox_inches="tight", transparent=True)

# %%
# result_ = pd.DataFrame({})
# for name in ['phos_num','area', 'perimeter','major', 'minor']:
#     double_name = 'double_' + name
#     single_name = 'single_' + name
#     temp = pd.read_csv('/home/yuchen/' + name + '.csv')
#     result_[double_name] = temp['double']
#     result_[single_name] = temp['single']

# for parameter in ['single_dtf', 'single_dti', 'amp','subject']:
#     result_[parameter] = temp[parameter]
# result_['E1'] = temp['electrode_pair'].apply(lambda x: x.split('_')[0])
# result_['E2'] = temp['electrode_pair'].apply(lambda x: x.split('_')[1])

# # compute how close the prediction is
# score = []
# for subject_name in ['12-005','51-009','52-001']:
#     result_subj = result_[result_.subject == subject_name].reset_index(drop=True)
#     score_subj = np.zeros(len(result_subj))
    
#     # remove perimeter because across all 4402 images, perimeter and major aixs have 95% correlation
#     for parameter_name in ['area','major','minor','phos_num']:
#         double_param = 'double_' + parameter_name
#         single_param = 'single_' + parameter_name
        
#         score_subj += np.sqrt((result_subj[double_param] - result_subj[single_param]*\
#                         coef[subject_name][parameter_name])**2)
#     score.extend(score_subj.tolist())
    
# result_['score'] = score
# result_ = result_.sort_values(by=['score'])

# %%
fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 63))
fig.tight_layout()

ct = 0

for subject_name in ['12-005','51-009','52-001']:
    bottom5 = result_[result_.subject == subject_name][-6:]
    
    for rank in range(6):
    
            
        temp = cate[(cate.subject == bottom5['subject'].iloc[rank]) &
                    (cate['electrode1'] == bottom5['E1'].iloc[rank]) & 
                    (cate['electrode2'] == bottom5['E2'].iloc[rank]) &
                   (cate['amp1'] == bottom5['amp'].iloc[rank])].reset_index(drop=True)
        if len(temp)!=1: print('warning')

        for i in range(len(temp)):
            f1 = cate[(cate.electrode1 == temp.electrode1[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
            f2 = cate[(cate.electrode1 == temp.electrode2[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]

            if not f1.empty and not f2.empty:
                
                if ct<=2:
                    axs[ct,0].imshow(f1.avg_image.iloc[0],cmap = 'gray_r')
                    axs[ct,1].imshow(f2.avg_image.iloc[0],cmap = 'gray_r')       
                    axs[ct,2].imshow(temp.avg_image[i],cmap = 'gray_r')
                elif ct>2 and ct<=5:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.2,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.2,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                else:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.7,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.7,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                    
                axs[ct,0].set_title(f1.electrode1.iloc[0] + ' ' + f1.electrode2.iloc[0], size=25) 
                axs[ct,1].set_title(f2.electrode1.iloc[0] + ' ' + f2.electrode2.iloc[0], size=25) 
                axs[ct,2].set_title(temp.electrode1[i] + ' ' + temp.electrode2[i] + ' ' + str(temp.subject[i]), size=25)     
                for j in range(3):
                    axs[ct,j].set_xticks([])
                    axs[ct,j].set_yticks([])
                ct +=1
for j in range(3):
    axs[0,j].set(xlim=(115,315), ylim=(315,165))  
    axs[1,j].set(xlim=(175,375), ylim=(300,150))  
    axs[2,j].set(xlim=(125,325), ylim=(325,175)) 
    
    axs[3,j].set(xlim=(75,275), ylim=(250,100)) 
    axs[4,j].set(xlim=(75,275), ylim=(290,140))  
    axs[5,j].set(xlim=(0,200), ylim=(200,50))  
    
    axs[6,j].set(xlim=(50,250), ylim=(180,30))  
    axs[7,j].set(xlim=(50,250), ylim=(195,45))  
    axs[8,j].set(xlim=(0,200), ylim=(226,76)) 

fig.subplots_adjust(hspace=0.01)
fig.savefig('/home/yuchen/paper/bad.pdf', format='pdf', transparent=True)

# %%
fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 63))
fig.tight_layout()

ct = 0

for subject_name in ['12-005','51-009','52-001']:
    bottom5 = result_[result_.subject == subject_name][:6]
    
    for rank in range(6):
    
            
        temp = cate[(cate.subject == bottom5['subject'].iloc[rank]) &
                    (cate['electrode1'] == bottom5['E1'].iloc[rank]) & 
                    (cate['electrode2'] == bottom5['E2'].iloc[rank]) &
                   (cate['amp1'] == bottom5['amp'].iloc[rank])].reset_index(drop=True)
        if len(temp)!=1: print('warning')

        for i in range(len(temp)):
            f1 = cate[(cate.electrode1 == temp.electrode1[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
            f2 = cate[(cate.electrode1 == temp.electrode2[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]

            if not f1.empty and not f2.empty:
                
                if ct<=2:
                    axs[ct,0].imshow(f1.avg_image.iloc[0],cmap = 'gray_r')
                    axs[ct,1].imshow(f2.avg_image.iloc[0],cmap = 'gray_r')       
                    axs[ct,2].imshow(temp.avg_image[i],cmap = 'gray_r')
                elif ct>2 and ct<=5:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.2,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.2,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                else:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.7,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.7,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                    
                axs[ct,0].set_title(f1.electrode1.iloc[0] + ' ' + f1.electrode2.iloc[0], size=25) 
                axs[ct,1].set_title(f2.electrode1.iloc[0] + ' ' + f2.electrode2.iloc[0], size=25) 
                axs[ct,2].set_title(temp.electrode1[i] + ' ' + temp.electrode2[i] + ' ' + str(temp.subject[i]), size=25)     
                for j in range(3):
                    axs[ct,j].set_xticks([])
                    axs[ct,j].set_yticks([])
                ct +=1
for j in range(3):
    axs[0,j].set(xlim=(115,315), ylim=(315,165))  
    axs[1,j].set(xlim=(175,375), ylim=(300,150))  
    axs[2,j].set(xlim=(125,325), ylim=(325,175)) 
    
    axs[3,j].set(xlim=(75,275), ylim=(250,100)) 
    axs[4,j].set(xlim=(75,275), ylim=(290,140))  
    axs[5,j].set(xlim=(0,200), ylim=(200,50))  
    
    axs[6,j].set(xlim=(50,250), ylim=(180,30))  
    axs[7,j].set(xlim=(50,250), ylim=(195,45))  
    axs[8,j].set(xlim=(0,200), ylim=(226,76)) 

fig.subplots_adjust(hspace=0.01)
fig.savefig('/home/yuchen/paper/bad.pdf', format='pdf', transparent=True)

# %%
fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 63))
fig.tight_layout()

ct = 0
for subject_name in ['12-005','51-009','52-001']:
    top5 = result_[result_.subject == subject_name][:6]
    
    for rank in range(6):
        temp = cate[(cate.subject == top5['subject'].iloc[rank]) &
                    (cate['electrode1'] == top5['E1'].iloc[rank]) & 
                    (cate['electrode2'] == top5['E2'].iloc[rank]) &
                   (cate['amp1'] == top5['amp'].iloc[rank])].reset_index(drop=True)
        if len(temp)!=1: print('warning')
            
        if subject_name == '12-005' and rank==3:
            break
        elif subject_name == '51-009' and rank not in [0,1,3]:
            continue
        elif subject_name == '52-001' and rank not in [2,4,5]:
            continue

        for i in range(len(temp)):

            f1 = cate[(cate.electrode1 == temp.electrode1[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
            f2 = cate[(cate.electrode1 == temp.electrode2[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]

            if not f1.empty and not f2.empty:
                if ct<=4:
                    axs[ct,0].imshow(f1.avg_image.iloc[0],cmap = 'gray_r')
                    axs[ct,1].imshow(f2.avg_image.iloc[0],cmap = 'gray_r')       
                    axs[ct,2].imshow(temp.avg_image[i],cmap = 'gray_r')
                elif ct==5:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.2,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.2,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                else:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.5,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.5,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                    
                axs[ct,0].set_title(f1.electrode1.iloc[0] + ' ' + f1.electrode2.iloc[0], size=25) 
                axs[ct,1].set_title(f2.electrode1.iloc[0] + ' ' + f2.electrode2.iloc[0], size=25) 
                axs[ct,2].set_title(temp.electrode1[i] + ' ' + temp.electrode2[i] + ' ' + str(temp.subject[i]), size=25)     
                for j in range(3):
                    axs[ct,j].set_xticks([])
                    axs[ct,j].set_yticks([])
                ct +=1

for j in range(3):
    axs[0,j].set(xlim=(100,300), ylim=(300,150))  
    axs[1,j].set(xlim=(50,250), ylim=(340,190))  
    axs[2,j].set(xlim=(200,400), ylim=(185,35)) 
    
    axs[3,j].set(xlim=(75,275), ylim=(215,65)) 
    axs[4,j].set(xlim=(75,275), ylim=(235,85))  
    axs[5,j].set(xlim=(50,250), ylim=(280,130))  
    
    axs[6,j].set(xlim=(50,250), ylim=(235,85))  
    axs[7,j].set(xlim=(25,225), ylim=(200,50))  
    axs[8,j].set(xlim=(65,265), ylim=(210,60)) 
fig.tight_layout()
fig.savefig('/home/yuchen/paper/good.pdf', format='pdf', transparent=True)

# %%
fig, axs= plt.subplots(ncols=3, nrows = 9, figsize=(21, 63))
fig.tight_layout()

ct = 0

for subject_name in ['12-005','51-009','52-001']:
    bottom5 = result_[result_.subject == subject_name][-6:]
    
    for rank in range(6):
        
        if subject_name == '12-005' and  rank not in [1,2,5]:
            continue
        elif subject_name == '51-009' and rank not in [0,1,5]:
            continue
        elif subject_name == '52-001' and rank not in [1,3,4]:
            continue
            
        temp = cate[(cate.subject == bottom5['subject'].iloc[rank]) &
                    (cate['electrode1'] == bottom5['E1'].iloc[rank]) & 
                    (cate['electrode2'] == bottom5['E2'].iloc[rank]) &
                   (cate['amp1'] == bottom5['amp'].iloc[rank])].reset_index(drop=True)
        if len(temp)!=1: print('warning')

        for i in range(len(temp)):
            f1 = cate[(cate.electrode1 == temp.electrode1[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
            f2 = cate[(cate.electrode1 == temp.electrode2[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]

            if not f1.empty and not f2.empty:
                
                if ct<=2:
                    axs[ct,0].imshow(f1.avg_image.iloc[0],cmap = 'gray_r')
                    axs[ct,1].imshow(f2.avg_image.iloc[0],cmap = 'gray_r')       
                    axs[ct,2].imshow(temp.avg_image[i],cmap = 'gray_r')
                elif ct>2 and ct<=5:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.2,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.2,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                else:
                    new_height = int(round(f1.avg_image.iloc[0].shape[0]/1.7,0))
                    new_width = int(round(f1.avg_image.iloc[0].shape[1]/1.7,0))
                    axs[ct,0].imshow(cv2.resize(f1.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')
                    axs[ct,1].imshow(cv2.resize(f2.avg_image.iloc[0], (new_width, new_height)),cmap = 'gray_r')       
                    axs[ct,2].imshow(cv2.resize(temp.avg_image[i], (new_width, new_height)),cmap = 'gray_r')
                    
                axs[ct,0].set_title(f1.electrode1.iloc[0] + ' ' + f1.electrode2.iloc[0], size=25) 
                axs[ct,1].set_title(f2.electrode1.iloc[0] + ' ' + f2.electrode2.iloc[0], size=25) 
                axs[ct,2].set_title(temp.electrode1[i] + ' ' + temp.electrode2[i] + ' ' + str(temp.subject[i]), size=25)     
                for j in range(3):
                    axs[ct,j].set_xticks([])
                    axs[ct,j].set_yticks([])
                ct +=1
for j in range(3):
    axs[0,j].set(xlim=(115,315), ylim=(315,165))  
    axs[1,j].set(xlim=(175,375), ylim=(300,150))  
    axs[2,j].set(xlim=(125,325), ylim=(325,175)) 
    
    axs[3,j].set(xlim=(75,275), ylim=(250,100)) 
    axs[4,j].set(xlim=(75,275), ylim=(290,140))  
    axs[5,j].set(xlim=(0,200), ylim=(200,50))  
    
    axs[6,j].set(xlim=(50,250), ylim=(180,30))  
    axs[7,j].set(xlim=(50,250), ylim=(195,45))  
    axs[8,j].set(xlim=(0,200), ylim=(226,76)) 

fig.subplots_adjust(hspace=0.01)
fig.savefig('/home/yuchen/paper/bad.pdf', format='pdf', transparent=True)

# %%
# temp = cate[(cate.subject == '52-001') 
#             &  (cate['electrode1'] == 'B7') & (cate['electrode2'] == 'D7')].reset_index(drop=True)
# # temp = cate[(cate['subject'] == '12-005') & (cate['amp1']==2)
# # &  (cate['electrode1'] == 'C7') & (cate['electrode2'] == 'D7')].reset_index(drop=True)
# # temp = temp.sort_values(by=['electrode1','electrode2']).reset_index(drop=True)
# for i in range(len(temp)):
#     f1 = cate[(cate.electrode1 == temp.electrode1[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
#     f2 = cate[(cate.electrode1 == temp.electrode2[i]) & (cate.electrode2 == str()) & (cate.amp1 == temp.amp1[i]) & (cate.freq == temp.freq[i]) & (cate.subject == temp.subject[i])]
    
#     if not f1.empty and not f2.empty:
#         fig, axs= plt.subplots(ncols=3, nrows = 1, figsize=(21, 7))
#         axs[0].imshow(f1.avg_image.iloc[0],cmap = 'gray')
#         axs[1].imshow(f2.avg_image.iloc[0],cmap = 'gray')       
#         axs[2].imshow(temp.avg_image[i],cmap = 'gray')
#         axs[0].set_title(f1.electrode1.iloc[0] + ' ' + f1.electrode2.iloc[0], size=25) 
#         axs[1].set_title(f2.electrode1.iloc[0] + ' ' + f2.electrode2.iloc[0], size=25) 
#         axs[2].set_title(temp.electrode1[i] + ' ' + temp.electrode2[i] + ' ' + str(temp.amp1[i]), size=25) 
#         for j in range(3):
#             axs[j].axis('off')

# %%
# temp = cate[(cate.subject == '12-005') 
#             &  (cate['electrode1'] == 'A6') ].reset_index(drop=True)
# temp

# %%
# temp = cate[cate.electrode2 != str()].reset_index(drop=True)
# temp = temp[(temp['subject'] == '12-005') 
#             &  (temp['electrode1'] == 'A1') & (temp['electrode2'] == 'A6')].reset_index(drop=True)
